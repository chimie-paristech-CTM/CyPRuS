# %% [markdown]
# # Regression Model Cross-Validation using Fingerprints

# %%
import random 
from random import sample, seed, shuffle
import numpy as np
import pandas as pd
import os
import six
from rdkit import rdBase
from rdkit import RDLogger

# Suppress RDKit warnings
rdBase.DisableLog('rdApp.*')
RDLogger.DisableLog('rdApp.*')

#utility functions : prepare the data 
from model_fp_selection.lib.utils import prepare_df_morgan, prepare_df_rdkit, swap_identical_ligands
from model_fp_selection.lib.utils import drop_duplicates, average_duplicates

#utility functions : CV and results 
from model_fp_selection.lib.utils import obtain_metrics, plot_cv_results
from model_fp_selection.lib.utils import df_split, get_indices, get_indices_doi, get_indices_scaff
from model_fp_selection.lib.utils import generate_scaffold, scaffold_to_smiles
from model_fp_selection.lib.utils import ligands_permutation, cross_validation, prepare_train_set


from rdkit import Chem
from rdkit.Chem import AllChem, DataStructs, Draw
from rdkit.ML.Descriptors.MoleculeDescriptors import MolecularDescriptorCalculator
from sklearn.model_selection import KFold, GridSearchCV
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error, median_absolute_error, PredictionErrorDisplay
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_validate
from sklearn.metrics.pairwise import rbf_kernel
from sklearn.preprocessing import MinMaxScaler

#Encoding categorical Data
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder
from sklearn.preprocessing import StandardScaler

# Regressors
from sklearn.ensemble import RandomForestRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import GradientBoostingRegressor

#Pipelines and other model constructions
from sklearn.pipeline import make_pipeline
from sklearn.compose import ColumnTransformer

# Visualization
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 20})

#np.random.seed(42)
#seed(42)

#Specific to Scaffold Splitting
from rdkit.Chem.Scaffolds import MurckoScaffold
from collections import defaultdict
import pickle as pkl
import time
from tqdm import tqdm
import seaborn as sns

from itertools import *

# %% [markdown]
# ## Preparing the dataset
#
# ***Maybe this should be rephrased since Morgan fp are now used with 1024 bits***
#
# Bayesian Optimisation allowed us to get the best hyperparameters for the random forest model, depending on the Fingerprint used. The Morgan Fingerprint with the best results was for **n=2, bits=2048**.

# %%
metals = pd.read_csv("ruthenium_complexes_dataset.csv", dtype={'L1': str, 'L2': str, 'L3': str})

# %%
metals_morgan = prepare_df_morgan(metals, 2, 1024)
metals_rdkit = prepare_df_rdkit(metals, nbits=2048)

# %%
metals_morgan = average_duplicates(metals_morgan, 'Ligands_Dict', 'pIC50')
# Out:
# Length of training dataset after cleaning duplicates, before adding permutations : 718

# %%
metals_rdkit = average_duplicates(metals_rdkit, 'Ligands_Dict', 'pIC50')
# Out:
# Length of training dataset after cleaning duplicates, before adding permutations : 718

# %% [markdown]
# ## Splitting the dataset
#
# We can split the dataset in different manners.
# - First, we can split it so that no permutation groups are split between training and testing set. The splitting indices are given by the function **get_indices**.
# - We can also split by DOI, so that two complexes from the same paper always end up in the same set. The splitting indices are given by the function **get_indices_doi**.
# - We can also split by scaffold, so that two complexes sharing a similar scaffold end up in the same set. The splitting indices are given by the function **get_indices_scaffold**.

# %% [markdown]
# # Training the model
#
# Bayesian Optimisation allowed us to get the best hyperparameters for the random forest model, depending on the Fingerprint used. The Morgan Fingerprint with the best results was for **n=2, bits=2048**.

# %%
rf_morgan = RandomForestRegressor(max_depth=27, n_estimators=140, min_samples_leaf=1, max_features=0.2, random_state=42)

# %%
rf_rdkit = RandomForestRegressor(max_depth=15, n_estimators=50, min_samples_leaf=1, max_features=0.5, random_state=42)

# %% [markdown]
# **TO BE DETAILLED AND EXPLAINED BETTER**
#
# - we keep the idea of expanding the dataset with permutations but that should only be the case for the training set, not the test set
# - we keep the scaler but we fit it on the training set only (and then scale it), and use the acquired parameters to scale the testing set.
#
# These preparations are doing within the cross validation function.

# %% [markdown]
# ## Standart Splitting
#
# #### On the whole dataset, Morgan fingerprint

# %%
metals_morgan_copy = metals_morgan.copy()
metals_morgan_copy.reset_index(drop=True, inplace=True)

X = np.array(metals_morgan_copy['Fingerprint'].values.tolist())
y = np.array(metals_morgan_copy['pIC50'].values.tolist())

indices_morgan = get_indices(metals_morgan_copy, CV=10)
# Out:
# train length : 646 | test length : 72
# 646 72
# train length : 646 | test length : 72
# 646 72
# train length : 646 | test length : 72
# 646 72
# train length : 646 | test length : 72
# 646 72
# train length : 646 | test length : 72
# 646 72
# train length : 646 | test length : 72
# 646 72
# train length : 646 | test length : 72
# 646 72
# train length : 646 | test length : 72
# 646 72
# train length : 646 | test length : 72
# 646 72
# train length : 646 | test length : 72
# 646 72

# %%
y_data_morgan, y_predictions_morgan = cross_validation(metals_morgan_copy, indices_morgan, X, y, rf_morgan)
# Out:
# CV iteration 0
# CV iteration 1
# CV iteration 2
# CV iteration 3
# CV iteration 4
# CV iteration 5
# CV iteration 6
# CV iteration 7
# CV iteration 8
# CV iteration 9
# {'MAE': 0.3409282297210967, 'RMSE': 0.4739139169243776, 'Ratio': 1.3900694504297064, 'R² Score': 0.6938687827881103}

# %%
plot_cv_results(y_data_morgan, y_predictions_morgan, log=True)

# %% [markdown]
# #### On the whole dataset, RDKit fingerprint

# %%
metals_rdkit_copy = metals_rdkit.copy()
metals_rdkit_copy.reset_index(drop=True, inplace=True)

X = np.array(metals_rdkit_copy['Fingerprint'].values.tolist())
y = np.array(metals_rdkit_copy['pIC50'].values.tolist())

indices_rdkit = get_indices(metals_rdkit_copy, CV=10)
# Out:
# train length : 646 | test length : 72
# 646 72
# train length : 646 | test length : 72
# 646 72
# train length : 646 | test length : 72
# 646 72
# train length : 646 | test length : 72
# 646 72
# train length : 646 | test length : 72
# 646 72
# train length : 646 | test length : 72
# 646 72
# train length : 646 | test length : 72
# 646 72
# train length : 646 | test length : 72
# 646 72
# train length : 646 | test length : 72
# 646 72
# train length : 646 | test length : 72
# 646 72

# %%
y_data_rdkit, y_predictions_rdkit = cross_validation(metals_rdkit_copy, indices_rdkit, X, y, rf_rdkit)
# Out:
# CV iteration 0
# CV iteration 1
# CV iteration 2
# CV iteration 3
# CV iteration 4
# CV iteration 5
# CV iteration 6
# CV iteration 7
# CV iteration 8
# CV iteration 9
# {'MAE': 0.3352288501969243, 'RMSE': 0.45968275571966954, 'Ratio': 1.3712505813555038, 'R² Score': 0.7119783606524951}

# %%
plot_cv_results(y_data_rdkit, y_predictions_rdkit, log=True)

# %% [markdown]
# #### On HeLa, Morgan fingerprint

# %%
metals_morgan_hela = metals_morgan.copy()
metals_morgan_hela = metals_morgan_hela[metals_morgan_hela['Cells'] == 'HeLa']
metals_morgan_hela.reset_index(drop=True, inplace=True)

X_hela = np.array(metals_morgan_hela['Fingerprint'].values.tolist())
y_hela = np.array(metals_morgan_hela['pIC50'].values.tolist())

indices_morgan_hela = get_indices(metals_morgan_hela, CV=10)
# Out:
# train length : 164 | test length : 19
# 164 19
# train length : 164 | test length : 19
# 164 19
# train length : 164 | test length : 19
# 164 19
# train length : 164 | test length : 19
# 164 19
# train length : 164 | test length : 19
# 164 19
# train length : 164 | test length : 19
# 164 19
# train length : 164 | test length : 19
# 164 19
# train length : 164 | test length : 19
# 164 19
# train length : 164 | test length : 19
# 164 19
# train length : 164 | test length : 19
# 164 19

# %%
y_data_morgan_hela, y_predictions_morgan_hela = cross_validation(metals_morgan_hela, indices_morgan_hela, X_hela, y_hela, rf_morgan)
# Out:
# CV iteration 0
# CV iteration 1
# CV iteration 2
# CV iteration 3
# CV iteration 4
# CV iteration 5
# CV iteration 6
# CV iteration 7
# CV iteration 8
# CV iteration 9
# {'MAE': 0.252886938884099, 'RMSE': 0.3488840620984334, 'Ratio': 1.37960490817729, 'R² Score': 0.494936905894774}

# %%
plot_cv_results(y_data_morgan_hela, y_predictions_morgan_hela, log=True)

# %% [markdown]
# #### On HeLa, RDKit fingerprint

# %%
metals_rdkit_hela = metals_rdkit.copy()
metals_rdkit_hela = metals_rdkit_hela[metals_rdkit_hela['Cells'] == 'HeLa']
metals_rdkit_hela.reset_index(drop=True, inplace=True)

X_hela = np.array(metals_rdkit_hela['Fingerprint'].values.tolist())
y_hela = np.array(metals_rdkit_hela['pIC50'].values.tolist())

indices_rdkit_hela = get_indices(metals_rdkit_hela, CV=10)
# Out:
# train length : 164 | test length : 19
# 164 19
# train length : 164 | test length : 19
# 164 19
# train length : 164 | test length : 19
# 164 19
# train length : 164 | test length : 19
# 164 19
# train length : 164 | test length : 19
# 164 19
# train length : 164 | test length : 19
# 164 19
# train length : 164 | test length : 19
# 164 19
# train length : 164 | test length : 19
# 164 19
# train length : 164 | test length : 19
# 164 19
# train length : 164 | test length : 19
# 164 19

# %%
y_data_rdkit_hela, y_predictions_rdkit_hela = cross_validation(metals_rdkit_hela, indices_rdkit_hela, X_hela, y_hela, rf_rdkit)
# Out:
# CV iteration 0
# CV iteration 1
# CV iteration 2
# CV iteration 3
# CV iteration 4
# CV iteration 5
# CV iteration 6
# CV iteration 7
# CV iteration 8
# CV iteration 9
# {'MAE': 0.2454809687762073, 'RMSE': 0.3602772361536624, 'Ratio': 1.467638155209128, 'R² Score': 0.46141157036197267}

# %%
plot_cv_results(y_data_rdkit_hela, y_predictions_rdkit_hela, log=True)

# %% [markdown]
# ## DOI Splitting
#
# #### On the whole dataset, Morgan fingerprint

# %%
metals_morgan_doi = metals_morgan.copy()
metals_morgan_doi.reset_index(drop=True, inplace=True)

X_morgan_doi = np.array(metals_morgan_doi['Fingerprint'].values.tolist())
y_morgan_doi = np.array(metals_morgan_doi['pIC50'].values.tolist())

indices_morgan_doi = get_indices_doi(metals_morgan_doi, CV=10, sizes=(0.9, 0.1))
# Out:
# train length : 626 | test length : 91
# train length : 653 | test length : 64
# train length : 663 | test length : 54
# train length : 652 | test length : 65
# train length : 645 | test length : 72
# train length : 622 | test length : 95
# train length : 652 | test length : 65
# train length : 649 | test length : 68
# train length : 645 | test length : 72
# train length : 646 | test length : 71

# %%
y_data_morgan_doi, y_predictions_morgan_doi = cross_validation(metals_morgan_doi, indices_morgan_doi, X_morgan_doi, y_morgan_doi, rf_morgan)
# Out:
# CV iteration 0
# CV iteration 1
# CV iteration 2
# CV iteration 3
# CV iteration 4
# CV iteration 5
# CV iteration 6
# CV iteration 7
# CV iteration 8
# CV iteration 9
# {'MAE': 0.49520480765843405, 'RMSE': 0.6883783358926882, 'Ratio': 1.390088151905615, 'R² Score': 0.319172176157294}

# %%
plot_cv_results(y_data_morgan_doi, y_predictions_morgan_doi, log=True)

# %% [markdown]
# #### On the whole dataset, RDKit fingerprint

# %%
metals_rdkit_doi = metals_rdkit.copy()
metals_rdkit_doi.reset_index(drop=True, inplace=True)

X_rdkit_doi = np.array(metals_rdkit_doi['Fingerprint'].values.tolist())
y_rdkit_doi = np.array(metals_rdkit_doi['pIC50'].values.tolist())

indices_rdkit_doi = get_indices_doi(metals_rdkit_doi, CV=10, sizes=(0.9, 0.1))
# Out:
# train length : 626 | test length : 91
# train length : 653 | test length : 64
# train length : 663 | test length : 54
# train length : 652 | test length : 65
# train length : 645 | test length : 72
# train length : 622 | test length : 95
# train length : 652 | test length : 65
# train length : 649 | test length : 68
# train length : 645 | test length : 72
# train length : 646 | test length : 71

# %%
y_data_rdkit_doi, y_predictions_rdkit_doi = cross_validation(metals_rdkit_doi, indices_rdkit_doi, X_rdkit_doi, y_rdkit_doi, rf_rdkit)
# Out:
# CV iteration 0
# CV iteration 1
# CV iteration 2
# CV iteration 3
# CV iteration 4
# CV iteration 5
# CV iteration 6
# CV iteration 7
# CV iteration 8
# CV iteration 9
# {'MAE': 0.5207101747034112, 'RMSE': 0.7108263625580864, 'Ratio': 1.365109416121862, 'R² Score': 0.27404456628778207}

# %%
plot_cv_results(y_data_rdkit_doi, y_predictions_rdkit_doi, log=True)

# %% [markdown]
# ## Scaffold Splitting

# %% [markdown]
# Whenever the complexe presents a AAB structure, it has been canonicalized in the 'prepare_df' function, so that any complexes represented as ABA or BAA is put in the form AAB.

# %% [markdown]
# #### Scaffold for ligand A, Morgan Fingerprint

# %%
metals_A = metals_morgan.copy()
metals_A.reset_index(drop=True, inplace=True)

X_A = np.array(metals_A['Fingerprint'].values.tolist())
y_A = np.array(metals_A['pIC50'].values.tolist())

# We must extract the mol objects as the get_indices_scaff take a list of mol objects as argument, not a dataframe
molsA = metals_A['MOL1'].tolist()

indicesA = get_indices_scaff(molsA, CV=10, sizes=(0.9, 0.1))
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 718/718 [00:00<00:00, 6825.26it/s]
# train length : 651 | test length : 67
# train length : 689 | test length : 29
# train length : 684 | test length : 34
# train length : 701 | test length : 17
# train length : 706 | test length : 12
# train length : 712 | test length : 6
# train length : 507 | test length : 211
# train length : 705 | test length : 13
# train length : 709 | test length : 9
# train length : 398 | test length : 320

# %%
y_dataA, y_predictionsA = cross_validation(metals_A, indicesA, X_A, y_A, rf_morgan)
# Out:
# CV iteration 0
# CV iteration 1
# CV iteration 2
# CV iteration 3
# CV iteration 4
# CV iteration 5
# CV iteration 6
# CV iteration 7
# CV iteration 8
# CV iteration 9
# {'MAE': 0.5200243628072103, 'RMSE': 0.7397937861678678, 'Ratio': 1.4226137063546254, 'R² Score': 0.21328124465820453}

# %%
plot_cv_results(y_dataA, y_predictionsA, log=True)

# %% [markdown]
# #### Scaffold for ligand A, RDKit Fingerprint

# %%
metals_A = metals_rdkit.copy()
metals_A.reset_index(drop=True, inplace=True)

X_A = np.array(metals_A['Fingerprint'].values.tolist())
y_A = np.array(metals_A['pIC50'].values.tolist())

# We must extract the mol objects as the get_indices_scaff take a list of mol objects as argument, not a dataframe
molsA = metals_A['MOL1'].tolist()

indicesA = get_indices_scaff(molsA, CV=10, sizes=(0.9, 0.1))
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 718/718 [00:00<00:00, 6903.05it/s]
# train length : 651 | test length : 67
# train length : 689 | test length : 29
# train length : 684 | test length : 34
# train length : 701 | test length : 17
# train length : 706 | test length : 12
# train length : 712 | test length : 6
# train length : 507 | test length : 211
# train length : 705 | test length : 13
# train length : 709 | test length : 9
# train length : 398 | test length : 320

# %%
y_dataA, y_predictionsA = cross_validation(metals_A, indicesA, X_A, y_A, rf_rdkit)
# Out:
# CV iteration 0
# CV iteration 1
# CV iteration 2
# CV iteration 3
# CV iteration 4
# CV iteration 5
# CV iteration 6
# CV iteration 7
# CV iteration 8
# CV iteration 9
# {'MAE': 0.5126114237372614, 'RMSE': 0.7261122056209178, 'Ratio': 1.4164963401070945, 'R² Score': 0.2421109721351148}

# %%
plot_cv_results(y_dataA, y_predictionsA, log=True)

# %% [markdown]
# #### Scaffold for ligand B, Morgan Fingerprint

# %%
metals_B = metals_morgan.copy()
metals_B.reset_index(drop=True, inplace=True)

X_B = np.array(metals_B['Fingerprint'].values.tolist())
y_B = np.array(metals_B['pIC50'].values.tolist())

# We must extract the mol objects as the get_indices_scaff take a list of mol objects as argument, not a dataframe
molsB = metals_B['MOL3'].tolist()

indicesB = get_indices_scaff(molsB, CV=10, sizes=(0.9, 0.1))
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 718/718 [00:00<00:00, 1328.15it/s]
# train length : 676 | test length : 42
# train length : 577 | test length : 141
# train length : 672 | test length : 46
# train length : 594 | test length : 124
# train length : 673 | test length : 45
# train length : 677 | test length : 41
# train length : 601 | test length : 117
# train length : 647 | test length : 71
# train length : 674 | test length : 44
# train length : 671 | test length : 47

# %%
y_dataB, y_predictionsB = cross_validation(metals_B, indicesB, X_B, y_B, rf_morgan)
# Out:
# CV iteration 0
# CV iteration 1
# CV iteration 2
# CV iteration 3
# CV iteration 4
# CV iteration 5
# CV iteration 6
# CV iteration 7
# CV iteration 8
# CV iteration 9
# {'MAE': 0.4707555639245666, 'RMSE': 0.6521317834270942, 'Ratio': 1.3852874684909537, 'R² Score': 0.38867961210555935}

# %%
plot_cv_results(y_dataB, y_predictionsB, log=True)

# %% [markdown]
# #### Scaffold for ligand B, RDKit Fingerprint

# %%
metals_B = metals_rdkit.copy()
metals_B.reset_index(drop=True, inplace=True)

X_B = np.array(metals_B['Fingerprint'].values.tolist())
y_B = np.array(metals_B['pIC50'].values.tolist())

# We must extract the mol objects as the get_indices_scaff take a list of mol objects as argument, not a dataframe
molsB = metals_B['MOL3'].tolist()

indicesB = get_indices_scaff(molsB, CV=10, sizes=(0.9, 0.1))
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 718/718 [00:00<00:00, 1527.48it/s]
# train length : 676 | test length : 42
# train length : 577 | test length : 141
# train length : 672 | test length : 46
# train length : 594 | test length : 124
# train length : 673 | test length : 45
# train length : 677 | test length : 41
# train length : 601 | test length : 117
# train length : 647 | test length : 71
# train length : 674 | test length : 44
# train length : 671 | test length : 47

# %%
y_dataB, y_predictionsB = cross_validation(metals_B, indicesB, X_B, y_B, rf_rdkit)
# Out:
# CV iteration 0
# CV iteration 1
# CV iteration 2
# CV iteration 3
# CV iteration 4
# CV iteration 5
# CV iteration 6
# CV iteration 7
# CV iteration 8
# CV iteration 9
# {'MAE': 0.4810454483320736, 'RMSE': 0.642007329980847, 'Ratio': 1.3346084703781642, 'R² Score': 0.4075139647028513}

# %%
plot_cv_results(y_dataB, y_predictionsB, log=True)
